# %% [markdown]
# ### **7.9 - [Practica] Deploy and run Airflow with the Kubernetes Executor on EKS**

# %% [markdown]
# Finally the best part. In this video we are going to install and execute our first DAG using Airflow through
#
# the Kubernetes Executor inside our EKS cluster. As we did for the nginx ingress,
#
# we are going to use Catalogs in order to install Airflow in the cluster. Since I already made a chart
#
# for running Airflow with the KubernetesExecutor.
#
# The first step is to add the catalog where the template is. Click on “airflowekscluster”, “Global”, “Apps”,
#
# and “Manage Catalog”.
#
# Here we need to add a new catalog with the name “airflow-eks”.
#
# and type the URL “https://github.com
#
# /marclamberti
#
# /airflow
#
# -helm-chart.git”
#
# all right now click on Create
#
# Check that the branch “master” is well selected and the scope is global. If your scope is not global by
#
# default, close the window and repeat the previous steps we did to add a new catalog. Before clicking
#
# on create, verify that you have the same inputs as mine and if everything is ok, click on the button.
#
# The catalog has been added and is active, we can install Airflow. Click on “Apps”, “Launch”, and select “airflow
#
# -kubernetes-eks”. As we did for the nginx-ingress, we need to define a name, let’s say
#
# airflow-eks
#
# The template version is the latest. The target project is default under the airflowekscluster. We keep
#
# the upgrade strategy and switch the role from “Project” to “Cluster”. Good. Click on “Launch” to start deploying
#
# Airflow on the cluster.
#
# Now, next to the “nginx-ingress” app, airflow is installing. Click on it. From there, wait for workloads,
#
# “postgres”, “scheduler” and “web” to be active and running.
#
# This process can take up to 10 minutes
#
# so in the meantime, you can click on any workload to get more information about what is doing.
#
# I'm going to put the video right now and come back when everything is ready.
#
# All right,
#
# at this point you should have the same output than me with all workloads in active state and running.
#
# Now, if you go on “Apps”, then select nginx-ingress
#
# and click on the endpoint just below the nginx controller service,
#
# you will land on the Airflow user interface.
#
# Well done,
#
# you have a fresh new install of Airflow running inside your EKS cluster with the KubernetesExecutor
#
# configured. To show you that I’m not lying,
#
# let’s execute some tasks. Before doing this,
#
# select your cluster from the top left corner and run kubectl by clicking here.
#
# Once we are connected, type “kubectl get namespaces”
#
# and copy the namespace starting by airflow.
#
# Then, type “watch kubectl get pods
#
# -n”, and paste the namespace.
#
# Enter. This command allows you to watch your pods in real time.
#
# So if we trigger a DAG, you should be able to see your tasks running from this view in your Kubernetes
#
# cluster. In the Airflow UI,
#
# turn on the toggle of the DAG parallel_dag and go back to the Rancher UI.
#
# As you can see, PODs corresponding to your tasks are running inside your EKS cluster
#
# with the Kubernetes executor.
#
# So that's it for this video.
#
# At this point you have learned everything you need to set up your own EKS cluster with airflow running
#
# and configured with the Kubernetes executor.
#
# If you're interested in learning more about it.
#
# Please don't hesitate to reach me in the Q/A section of Udemy or by messages.
#
# I will be happy to answer you. Now, let's take a quick break and see you for the next video.
