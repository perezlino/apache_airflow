# %% [markdown]
# ### **3.11 - Executing Python Functions**

# %% [markdown]
# #### **`PythonOperator`**
#
# Para usar el operador **`PythonOperator`** debemos importarlo:
#
# <center><img src="https://i.postimg.cc/mrQ71tSc/a143.png"></center>
# <center><img src="https://i.postimg.cc/65yRLH0x/a144.png"></center>
#
# ¿Y después qué? Bueno, el PythonOperator espera la función Python Callable, y este es el nombre del parámetro. Tienes que especificar dónde estará la función de Python:
#
# <center><img src="https://i.postimg.cc/vHknPWqg/a145.png"></center>
# <center><img src="https://i.postimg.cc/Z5NdXC2f/a146.png"></center>
#
# Vamos a probarlo:
#
# 1.	Guardamos el archivo .py
# 2.	Vamos a la UI y refrescamos el sitio
#
# <center><img src="https://i.postimg.cc/Vs7ntyXF/a147.png"></center>
#
# 3.	Apagamos el Toggle y luego nos dirigimos a Browse > DAG Runs
#
# <center><img src="https://i.postimg.cc/5ytzrpWv/a148.png"></center>
#
# 4.	Seleccionamos los DAG Runs y los eliminamos
#
# <center><img src="https://i.postimg.cc/d3SCcdJf/a149.png"></center>
#
# 5.	Regresamos y encendemos el Toggle y refrescamos el sitio
#
# <center><img src="https://i.postimg.cc/XJLFxmm4/a150.png"></center>
#
# 6.	Trigger DAG
#
# <center><img src="https://i.postimg.cc/PxTYWT6S/a151.png"></center>
# <center><img src="https://i.postimg.cc/8CV6GTVT/a152.png"></center>
#
# 7.	Vemos que se está ejecutando un DAG. Refrescamos el sitio
#
# <center><img src="https://i.postimg.cc/GpJsh6cG/a153.png"></center>
#
# 8.	Vemos que finalizó con éxito y damos clic sobre él:
#
# <center><img src="https://i.postimg.cc/0QkK6ZQ3/a154.png"></center>
#
# 9.	Damos clic sobre el nombre del DAG
#
# <center><img src="https://i.postimg.cc/gJgX3RL0/a155.png"></center>
#
# 10.	Damos clic sobre la tarea
#
# <center><img src="https://i.postimg.cc/WztD830w/a156.png"></center>
#
# 11.	Damos clic en LOG
#
# <center><img src="https://i.postimg.cc/tJfsMj5Q/a157.png"></center>
#
# 12.	Y podemos ver que se obtiene el texto “Just a test”
#
# <center><img src="https://i.postimg.cc/CM6n1GVP/a158.png"></center>
# <center><img src="https://i.postimg.cc/kX66t2Jn/a159.png"></center>
#
# ___

# %% [markdown]
# #### **`DagRun “context”`**
#
# Ahora, digamos que quieres acceder al "contexto" de tu DAG Run. Lo que quiero decir con "contexto", me refiero a la información relacionada con tu DAG Run. Por ejemplo, el execution date o el previous execution date o digamos, el next execution date. Permíteme mostrarte cómo puedes acceder al contexto de tu DAG Run en el que se ejecuta esa tarea. Lo único que tienes que hacer es escribir:
#
# <center><img src="https://i.postimg.cc/9F64Pc0y/a160.png"></center>
#
# Y ahora obtenemos este larguísimo diccionario correspondiente al contexto del DAG Run, donde se ejecutan las tareas. Y de ese contexto se obtiene mucha información.
#
# <center><img src="https://i.postimg.cc/jjXLrNXh/a161.png"></center>
#
# Digamos que queremos obtener la execution date ("ds"):
#
# <center><img src="https://i.postimg.cc/L8jJNGgw/a162.png"></center>
#
# Volvemos al código y modificamos lo siguiente:
#
# <center><img src="https://i.postimg.cc/cHL61HkG/a163.png"></center>
# <center><img src="https://i.postimg.cc/g0dn54vJ/a164.png"></center>
#
# Guardamos el archivo y volvemos a la UI. Seleccionamos GRAPH VIEW:
#
# <center><img src="https://i.postimg.cc/qRDqNTWh/a165.png"></center>
#
# Clic sobre la tarea y luego en “Clear”:
#
# <center><img src="https://i.postimg.cc/FzfRc6QP/a166.png"></center>
# <center><img src="https://i.postimg.cc/Y0JSxxrt/a167.png"></center>
#
# Luego damos clic en Ok:
#
# <center><img src="https://i.postimg.cc/xj7qY9KB/a168.png"></center>
#
# Refrescamos el sitio. Luego damos clic sobre la tarea:
#
# <center><img src="https://i.postimg.cc/4N9yxjPy/a169.png"></center>
#
# Luego damos clic en LOG:
#
# <center><img src="https://i.postimg.cc/0y1QMZXf/a170.png"></center>
#
# Y como ves obtenemos la “execution date” del DAG:
#
# <center><img src="https://i.postimg.cc/2Sd54vPf/a171.png"></center>
#
# Así es como se puede acceder a la información de contexto del DAG Run donde se está ejecutando la tarea.
#
# ___

# %% [markdown]
# #### **`Añadir parámetros propios`**
#
# Otra cosa que puedes hacer con el PythonOperator es añadir tus propios parámetros. Justo debajo de "python_callable", puedes decir:
#
# <center><img src="https://i.postimg.cc/5tx2pyVQ/a172.png"></center>
# <center><img src="https://i.postimg.cc/0Qj2R4r8/a173.png"></center>
#
# Otro ejemplo:
#
# <center><img src="https://i.postimg.cc/3wnJqh8S/a174.png"></center>
# <center><img src="https://i.postimg.cc/NMnGgxrR/a175.png"></center>
